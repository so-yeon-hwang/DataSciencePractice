# %% [markdown]
# <a href="https://colab.research.google.com/github/so-yeon-hwang/DataSciencePractice/blob/main/Web_Scraping_Kpop_Boy_Groups.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Draft

# %%
import requests
from bs4 import BeautifulSoup

# 웹 페이지 URL
# url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%9D%BC%EC%9D%B4%EC%A6%88&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231002to20231117,a:all&start=11"
url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=ZEROBASEONE&sort=1&photo=0&field=0&pd=3&ds=2023.10.09&de=2023.11.24&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231009to20231124,a:all&start=0'

# requests를 사용하여 HTML 가져오기
response = requests.get(url)
html = response.text

# BeautifulSoup을 사용하여 HTML 파싱
soup = BeautifulSoup(html, 'html.parser')

soup
# Out:
# <!DOCTYPE html>
# ...

# %%
titles = [a.get('title', '') for a in soup.find_all('a')]

headlines = []

# 결과 출력
for idx, title in enumerate(titles, start=1):
  headlines.append(title)

# %%
# headlines 리스트에서 'ZEROBASEONE'이 포함된 요소만 추출
filtered_headlines = [headline for headline in headlines if 'ZEROBASEONE' in headline.upper()]

# 결과 출력
for idx, filtered_headline in enumerate(filtered_headlines, start=1):
    print(f"Filtered Headline {idx}: {filtered_headline}")
# Out:
# Filtered Headline 1: 제로베이스원(ZEROBASEONE) 김지웅-성한빈-장하오, 강렬하지만 귀여운 포즈! [영상]

# %%
nums = []
for i in range(0, 3941, 10):
  if i == 0:
    nums.append(i)
  else:
    nums.append(i+1)

# %%
base_url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%9D%BC%EC%9D%B4%EC%A6%88&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231002to20231117,a:all&start="

# 페이지 번호에 해당하는 링크를 생성하여 리스트에 추가
links = [base_url + str(i) for i in nums]

# %%
total = 0
for i in links:
  response = requests.get(url)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser') # soup에 담기
  naver_news_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True))
  naver_news_count = len(naver_news_elements)
  total += naver_news_count

# %%
total
# Out:
# 395

# %%
# 텍스트에 '네이버뉴스'가 포함된 요소 찾기
naver_news_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True))

# '네이버뉴스'가 몇 번 나타나는지 세기
naver_news_count = len(naver_news_elements)

# 결과 출력
print("'네이버뉴스' 발견 횟수:", naver_news_count)
# Out:
# '네이버뉴스' 발견 횟수: 1

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# 텍스트에 '네이버뉴스'가 포함된 요소 찾기
naver_news_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True))

# '네이버뉴스'가 몇 번 나타나는지 세기
naver_news_count = len(naver_news_elements)

# 결과 출력
print("'네이버뉴스' 발견 횟수:", naver_news_count)
# Out:
# '네이버뉴스' 발견 횟수: 2

# %%
str(soup)
# Out:
# '<!DOCTYPE html>\n <html lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="라이즈 : 네이버 뉴스검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="\'라이즈\'의 네이버 뉴스검색 결과입니다." property="og:description"/> <meta content="\'라이즈\'의 네이버 뉴스검색 결과입니다." lang="ko" name="description"/> <title>라이즈 : 네이버 뉴스검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_231214.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net
# ...

# %%
naver_news_count = sum('네이버뉴스' in a.get('onclick', '') for a in soup.find_all('a'))
naver_news_count
# Out:
# 0

# %%
naver_news_element = soup.find('a', class_='네이버뉴스')
naver_news_element

# %%
nums = range(0, 3951, 10)
# Out:
# range(0, 3951, 10)

# %%
range(0,10)
# Out:
# range(0, 10)

# %%
nums = []
for i in range(0, 3941, 10):
  if i == 0:
    nums.append(i)
  else:
    nums.append(i+1)

# %%
nums

# %%
base_url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%9D%BC%EC%9D%B4%EC%A6%88&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231002to20231117,a:all&start="

# 페이지 번호에 해당하는 링크를 생성하여 리스트에 추가
links = [base_url + str(i) for i in nums]

# links 리스트 출력
for idx, link in enumerate(links):
    print(f"link{idx + 1}: {link}")
# Out:
# link1: https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%9D%BC%EC%9D%B4%EC%A6%88&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231002to20231117,a:all&start=0
# link2: https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%9D%BC%EC%9D%B4%EC%A6%88&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231002to20231117,a:all&start=11
# link3: https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%9D%BC%EC%9D%B4%EC%A6%88&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231002to20231117,a:all&start=21
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 웹 페이지 URL
base_url = "https://search.naver.com/search.naver?where=news&query=%EB%9D%BC%EC%9D%B4%EC%A6%88&sm=tab_opt&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Add%2Cp%3Afrom20231002to20231117&is_sug_officeid=0&office_category=0&service_area=0&start="

# 페이지 번호에 해당하는 링크를 생성하여 리스트에 추가
nums = range(0, 3951, 10)
links = [base_url + str(i) for i in nums]

# 각 페이지의 HTML을 담을 리스트
html_list = []

# 각 링크에 대해 HTML을 가져와서 리스트에 추가
for idx, link in enumerate(links):
    response = requests.get(link)
    html = response.text
    html_list.append(html)
    print(f"Page {idx + 1} HTML retrieved")

# html_list에는 각 페이지의 HTML이 들어있음
# Out:
# Page 1 HTML retrieved
# Page 2 HTML retrieved
# Page 3 HTML retrieved
# Page 4 HTML retrieved
# Page 5 HTML retrieved
# Page 6 HTML retrieved
# Page 7 HTML retrieved
# Page 8 HTML retrieved
# Page 9 HTML retrieved
# Page 10 HTML retrieved
# Page 11 HTML retrieved
# Page 12 HTML retrieved
# Page 13 HTML retrieved
# Page 14 HTML retrieved
# Page 15 HTML retrieved
# Page 16 HTML retrieved
# Page 17 HTML retrieved
# Page 18 HTML retrieved
# Page 19 HTML retrieved
# Page 20 HTML retrieved
# Page 21 HTML retrieved
# Page 22 HTML retrieved
# Page 23 HTML retrieved
# Page 24 HTML retrieved
# Page 25 HTML retrieved
# Page 26 HTML retrieved
# Page 27 HTML retrieved
# Page 28 HTML retrieved
# Page 29 HTML retrieved
# Page 30 HTML retrieved
# Page 31 HTML retrieved
# Page 32 HTML retrieved
# Page 33 HTML retrieved
# Page 34 HTML retrieved
# Page 35 HTML retrieved
# Page 36 HTML retrieved
# Page 37 HTML retrieved
# Page 38 HTML retrieved
# Page 39 HTML retrieved
# Page 40 HTML retrieved
# ...

# %%
print(html_list)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # 2. Code - '네이버뉴스'만 추출

# %%
### basic code source ###

import requests
from bs4 import BeautifulSoup

# 웹 페이지 URL
# url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%9D%BC%EC%9D%B4%EC%A6%88&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231002to20231117,a:all&start=11"

# requests를 사용하여 HTML 가져오기
response = requests.get(url)
html = response.text

# BeautifulSoup을 사용하여 HTML 파싱
soup = BeautifulSoup(html, 'html.parser')

nums = []
for i in range(0, 191, 10):
  if i == 0:
    nums.append(i)
  else:
    nums.append(i+1)

base_url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%9D%BC%EC%9D%B4%EC%A6%88&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231002to20231117,a:all&start="

# 페이지 번호에 해당하는 링크를 생성하여 리스트에 추가
links = [base_url + str(i) for i in nums]

total = 0

for i in links:
  response = requests.get(url)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser') # soup에 담기
  naver_news_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True))
  naver_news_count = len(naver_news_elements)
  total += naver_news_count

# %%
### searching info ###

# ZB1
# searching period : 2023.10.09~2023.11.24
# search : ZEROBASEONE

### code ###

import requests
from bs4 import BeautifulSoup

base_url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=ZEROBASEONE&sort=1&photo=0&field=0&pd=3&ds=2023.10.09&de=2023.11.24&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231009to20231124,a:all&start='

# 마지막 페이지 2061

nums = []
for i in range(0, 2061, 10):
  if i == 0:
    nums.append(i)
  else:
    nums.append(i+1)

links = [base_url + str(i) for i in nums]

total = 0

for i in links:
  response = requests.get(i)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser') # soup에 담기
  naver_news_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True))
  naver_news_count = len(naver_news_elements)
  print('카운트 : ' , naver_news_count)
  total += naver_news_count
  print('총 : ' , total)

print(total) # 902
# Out:
# 카운트 :  10
# 총 :  10
# 카운트 :  10
# 총 :  20
# 카운트 :  6
# 총 :  26
# 카운트 :  10
# 총 :  36
# 카운트 :  10
# 총 :  46
# 카운트 :  10
# 총 :  56
# 카운트 :  10
# 총 :  66
# 카운트 :  10
# 총 :  76
# 카운트 :  10
# 총 :  86
# 카운트 :  10
# 총 :  96
# 카운트 :  10
# 총 :  106
# 카운트 :  10
# 총 :  116
# 카운트 :  8
# 총 :  124
# 카운트 :  6
# 총 :  130
# 카운트 :  6
# 총 :  136
# 카운트 :  6
# 총 :  142
# 카운트 :  7
# 총 :  149
# 카운트 :  5
# 총 :  154
# 카운트 :  4
# 총 :  158
# 카운트 :  2
# 총 :  160
# 카운트 :  6
# 총 :  166
# 카운트 :  6
# 총 :  172
# 카운트 :  7
# 총 :  179
# 카운트 :  8
# 총 :  187
# 카운트 :  8
# 총 :  195
# 카운트 :  7
# 총 :  202
# 카운트 :  9
# 총 :  211
# 카운트 :  10
# 총 :  221
# 카운트 :  10
# 총 :  231
# 카운트 :  2
# 총 :  233
# 카운트 :  8
# 총 :  241
# 카운트 :  6
# 총 :  247
# 카운트 :  7
# 총 :  254
# 카운트 :  6
# 총 :  260
# 카운트 :  6
# 총 :  266
# 카운트 :  7
# 총 :  273
# 카운트 :  5
# 총 :  278
# 카운트 :  6
# 총 :  284
# 카운트 :  6
# 총 :  290
# 카운트 :  8
# 총 :  298
# 카운트 :  4
# 총 :  302
# 카운트 :  6
# 총 :  308
# 카운트 :  7
# 총 :  315
# 카운트 :  6
# 총 :  321
# 카운트 :  5
# 총 :  326
# ...

# %%
### searching info ###

# RIIZE
# searching period : 2023.10.02~2023.11.17
# search : RIIZE

### code ###

import requests
from bs4 import BeautifulSoup

base_url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=RIIZE&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231002to20231117,a:all&start='

# 마지막 페이지 1071

nums = []
for i in range(0, 1071, 10):
  if i == 0:
    nums.append(i)
  else:
    nums.append(i+1)

links = [base_url + str(i) for i in nums]
total = 0

for i in links:
  response = requests.get(i)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser') # soup에 담기
  naver_news_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True))
  naver_news_count = len(naver_news_elements)
  print('카운트 : ' , naver_news_count)
  total += naver_news_count
  print('총 : ' , total)

print(total) # 738
# Out:
# 카운트 :  5
# 총 :  5
# 카운트 :  4
# 총 :  9
# 카운트 :  6
# 총 :  15
# 카운트 :  3
# 총 :  18
# 카운트 :  6
# 총 :  24
# 카운트 :  4
# 총 :  28
# 카운트 :  5
# 총 :  33
# 카운트 :  6
# 총 :  39
# 카운트 :  6
# 총 :  45
# 카운트 :  6
# 총 :  51
# 카운트 :  7
# 총 :  58
# 카운트 :  7
# 총 :  65
# 카운트 :  7
# 총 :  72
# 카운트 :  4
# 총 :  76
# 카운트 :  6
# 총 :  82
# 카운트 :  6
# 총 :  88
# 카운트 :  8
# 총 :  96
# 카운트 :  5
# 총 :  101
# 카운트 :  6
# 총 :  107
# 카운트 :  10
# 총 :  117
# 카운트 :  10
# 총 :  127
# 카운트 :  10
# 총 :  137
# 카운트 :  7
# 총 :  144
# 카운트 :  8
# 총 :  152
# 카운트 :  9
# 총 :  161
# 카운트 :  9
# 총 :  170
# 카운트 :  9
# 총 :  179
# 카운트 :  5
# 총 :  184
# 카운트 :  2
# 총 :  186
# 카운트 :  7
# 총 :  193
# 카운트 :  6
# 총 :  199
# 카운트 :  7
# 총 :  206
# 카운트 :  6
# 총 :  212
# 카운트 :  3
# 총 :  215
# 카운트 :  4
# 총 :  219
# 카운트 :  4
# 총 :  223
# 카운트 :  4
# 총 :  227
# 카운트 :  8
# 총 :  235
# 카운트 :  8
# 총 :  243
# 카운트 :  10
# 총 :  253
# 카운트 :  10
# 총 :  263
# 카운트 :  10
# 총 :  273
# 카운트 :  10
# 총 :  283
# 카운트 :  9
# 총 :  292
# 카운트 :  10
# 총 :  302
# 카운트 :  10
# ...

# %%
len(links)
# Out:
# 108

# %%
url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=RIIZE&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231002to20231117,a:all&start=11'

# %%
response = requests.get(url)
html = response.text
soup = BeautifulSoup(html, 'html.parser') # soup에 담기
naver_news_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True))
naver_news_count = len(naver_news_elements)
total += naver_news_count

# %%
print(total)
# Out:
# 9

# %%
url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=ZEROBASEONE&sort=1&photo=0&field=0&pd=3&ds=2023.10.09&de=2023.11.24&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231009to20231124,a:all&start=0'

# requests를 사용하여 HTML 가져오기
response = requests.get(url)
html = response.text

# BeautifulSoup을 사용하여 HTML 파싱
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
from bs4 import BeautifulSoup


# '네이버뉴스'가 포함되어 있고, 제목에 'ZEROBASEONE'이 들어가는 요소 찾기
filtered_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True) and 'ZEROBASEONE' in tag.get('title', '').upper())

filtered_elements
# Out:
# []

# %% [markdown]
# # 3. 뉴스기사 제목만 추출

# %%
# ZB1
# searching period : 2023.10.09~2023.11.24
# search : ZEROBASEONE

### code ###

import requests
from bs4 import BeautifulSoup

base_url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=ZEROBASEONE&sort=1&photo=0&field=0&pd=3&ds=2023.10.09&de=2023.11.24&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=2&nso=so:dd,p:from20231009to20231124,a:all&start='

# 마지막 페이지 1731

nums = []
for i in range(0, 1731, 10):
  if i == 0:
    nums.append(i)
  else:
    nums.append(i+1)

links = [base_url + str(i) for i in nums]
headlines = []

for i in links:
  response = requests.get(i)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser') # 변수 soup에 각 페이지 별 정보 담기
  titles = [a.get('title', '') for a in soup.find_all('a')]
  for idx, title in enumerate(titles, start=1):
    headlines.append(title)

# %%
titles = [a.get('title', '') for a in soup.find_all('a')]
headlines = []

# 결과 출력
for idx, title in enumerate(titles, start=1):
  headlines.append(title)

# %%
# headlines 리스트에서 'ZEROBASEONE'이 포함된 요소만 추출
filtered_headlines = [headline for headline in headlines if 'ZEROBASEONE' in headline.upper()]

# 결과 출력
for idx, filtered_headline in enumerate(filtered_headlines, start=1):
    print(f"Filtered Headline {idx}: {filtered_headline}")
# Out:
# Filtered Headline 1: 제로베이스원(ZEROBASEONE) 김지웅-성한빈-장하오, 강렬하지만 귀여운 포즈! [영상]

# %%
# 17페이지까지만 예시로 돌려보기


# ZB1
# searching period : 2023.10.09~2023.11.24
# search : ZEROBASEONE

### code ###

import requests
from bs4 import BeautifulSoup

base_url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=ZEROBASEONE&sort=1&photo=0&field=0&pd=3&ds=2023.10.09&de=2023.11.24&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=2&nso=so:dd,p:from20231009to20231124,a:all&start='

# 마지막 페이지 1731

nums = []
for i in range(0, 171, 10):
  if i == 0:
    nums.append(i)
  else:
    nums.append(i+1)

links = [base_url + str(i) for i in nums]
headlines = []

for i in links:
  response = requests.get(i)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser') # 변수 soup에 각 페이지 별 정보 담기
  titles = [a.get('title', '') for a in soup.find_all('a')]

  for title in titles:
    headlines.append(title)

  filtered_headlines = [headline for headline in headlines if 'ZEROBASEONE' in headline.upper()]

print(filtered_headlines)
# Out:
# ['제로베이스원(ZEROBASEONE) 김지웅-성한빈-장하오, 강렬하지만 귀여운 포즈! [영상]', 'ZEROBASEONE, 한 편의 판타지 동화 공개']

# %%
len(filtered_headlines)
# Out:
# 2

# %%
# ZB1
# searching period : 2023.10.09~2023.11.24
# search : ZEROBASEONE

### code ###

import requests
from bs4 import BeautifulSoup

base_url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=ZEROBASEONE&sort=1&photo=0&field=0&pd=3&ds=2023.10.09&de=2023.11.24&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=2&nso=so:dd,p:from20231009to20231124,a:all&start='

# 마지막 페이지 1731

nums = []
for i in range(0, 1731, 10):
  if i == 0:
    nums.append(i)
  else:
    nums.append(i+1)

links = [base_url + str(i) for i in nums]
headlines = []

for i in links:
  response = requests.get(i)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser') # 변수 soup에 각 페이지 별 정보 담기
  titles = [a.get('title', '') for a in soup.find_all('a')]

  for title in titles:
    headlines.append(title)

  filtered_headlines = [headline for headline in headlines if 'ZEROBASEONE' in headline.upper()]

print(filtered_headlines)
print('===============================================')
print('')
print('주어진 범위 내에서 ZEROBASEONE이 포함된 헤드라인의 총 개수 : ' . len(filtered_headlines))
# Out:
# ['제로베이스원(ZEROBASEONE) 김지웅-성한빈-장하오, 강렬하지만 귀여운 포즈! [영상]', 'ZEROBASEONE, 한 편의 판타지 동화 공개', 'ZEROBASEONE, 일본 오리콘 주간 앨범 랭킹 2위', 'ZEROBASEONE(제로베이스원), 미니 2집 ‘MELTING POINT’로 中 QQ뮤직서 ‘골드 배지’ 인증', 'GS25 to launch new products in collaboration with ZEROBASEONE', "'Melting Point' by ZeroBaseOne sells over 2.1M copies in first week", 'ZEROBASEONE, 강렬한 변신+화려한 퍼포먼스', "ZEROBASEONE, 컴백 첫 주 음반·음원 폭발적 성장세로 '5세대 아이콘'", "스쿨룩스 모델에 신인그룹 '제로베이스원(ZEROBASEONE)' 발탁", '스쿨룩스, ‘제로베이스원(ZEROBASEONE)’ 모델 발탁', "스쿨룩스, 신예 보이그룹 '제로베이스원(ZEROBASEONE)' 전속모델 발탁", "보이그룹 '제로베이스원(ZEROBASEONE)' 스쿨룩스, 새 모델 된다", "Zerobaseone reaches 'Melting Point' with 2nd EP", "[SHOWCASE] 'Global mega rookie' ZeroBaseOne takes it all in with release of 'Melting Point'", "[사진]제로베이스원(ZEROBASEONE),'제로즈를 지키는 우리'", "[사진]제로베이스원(ZEROBASEONE),'제로즈를 지켜라'", "[사진]제로베이스원(ZEROBASEONE),'새로운 전설의 시작'", '[포토]제로베이스원(ZEROBASEONE), 강렬한 컴백', "[사진]제로베이스원(ZEROBASEONE),'멜팅 포인트'", "[사진]제로베이스원(ZEROBASEONE),'우리가 돌아왔어'", "[사진]제로베이스원(ZEROBASEONE),'제로즈 기다린 컴백'", 'ZEROBASEO
# ...

# %%
zb1_list = ['제로베이스원(ZEROBASEONE) 김지웅-성한빈-장하오, 강렬하지만 귀여운 포즈! [영상]',
            'ZEROBASEONE, 한 편의 판타지 동화 공개',
            'ZEROBASEONE, 일본 오리콘 주간 앨범 랭킹 2위',
            'ZEROBASEONE(제로베이스원), 미니 2집 ‘MELTING POINT’로 中 QQ뮤직서 ‘골드 배지’ 인증',
            'GS25 to launch new products in collaboration with ZEROBASEONE',
            "'Melting Point' by ZeroBaseOne sells over 2.1M copies in first week",
            'ZEROBASEONE, 강렬한 변신+화려한 퍼포먼스',
            "ZEROBASEONE, 컴백 첫 주 음반·음원 폭발적 성장세로 '5세대 아이콘'",
            "스쿨룩스 모델에 신인그룹 '제로베이스원(ZEROBASEONE)' 발탁",
            '스쿨룩스, ‘제로베이스원(ZEROBASEONE)’ 모델 발탁',
            "스쿨룩스, 신예 보이그룹 '제로베이스원(ZEROBASEONE)' 전속모델 발탁",
            "보이그룹 '제로베이스원(ZEROBASEONE)' 스쿨룩스, 새 모델 된다",
            "Zerobaseone reaches 'Melting Point' with 2nd EP",
            "[SHOWCASE] 'Global mega rookie' ZeroBaseOne takes it all in with release of 'Melting Point'",
            "[사진]제로베이스원(ZEROBASEONE),'제로즈를 지키는 우리'",
            "[사진]제로베이스원(ZEROBASEONE),'제로즈를 지켜라'",
            "[사진]제로베이스원(ZEROBASEONE),'새로운 전설의 시작'",
            '[포토]제로베이스원(ZEROBASEONE), 강렬한 컴백',
            "[사진]제로베이스원(ZEROBASEONE),'멜팅 포인트'",
            "[사진]제로베이스원(ZEROBASEONE),'우리가 돌아왔어'",
            "[사진]제로베이스원(ZEROBASEONE),'제로즈 기다린 컴백'",
            'ZEROBASEONE, 파워풀한 ‘CRUSH(가시)’ 음원 일부 공개',
            'ZEROBASEONE, 아홉 멤버가 직접 전하는 스포일러',
            'ZEROBASEONE, 결연한 맹세', "로맨틱크라운, 브랜드 보델 보이그룹 'ZEROBASEONE'과 함께한 23FW 아우터 컬렉션 공개",
            '로맨틱크라운, 제로베이스원(ZEROBASEONE)과 함께한 23FW 아우터 컬렉션 공개',
            '제로베이스원(Zerobaseone),’폭발적인 청량미’ [O! STAR]',
            "ZEROBASEONE Takes The Veil Off Their New Album's Title Song... Contains A Total Of 5 Songs",
            'ZEROBASEONE Releases Fairytale-like Concept Photos',
            '제로베이스원(ZB1, ZEROBASEONE), 100일 축하해요 (입국)[뉴스엔TV]',
            'ZEROBASEONE, 겨울 동화 속 순백 왕자 변신',
            'ZEROBASEONE, 동화 속 순백의 왕자 무드…콘셉트 포토',
            "ZEROBASEONE, 'ZBTV' Is Coming!",
            'ZEROBASEONE, 데뷔 앨범으로 더블 밀리언셀러 달성…K팝 최초',
            '컴백 앞둔 ZEROBASEONE, 20일 자체 콘텐츠 ‘ZBTV’ 개국']
len(zb1_list)
# Out:
# 35

# %%
### searching info ###

# RIIZE
# searching period : 2023.10.02~2023.11.17
# search : RIIZE

### code ###

import requests
from bs4 import BeautifulSoup

base_url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=RIIZE&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=1701&nso=so:dd,p:from20231002to20231117,a:all&start='

# 마지막 페이지 1071
# PC 언론사와 기존과 같음 !!

nums = []
for i in range(0, 1071, 10):
  if i == 0:
    nums.append(i)
  else:
    nums.append(i+1)

links = [base_url + str(i) for i in nums]
headlines = []

for i in links:
  response = requests.get(i)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser') # 변수 soup에 각 페이지 별 정보 담기
  titles = [a.get('title', '') for a in soup.find_all('a')]

  for title in titles:
    headlines.append(title)

  filtered_headlines = [headline for headline in headlines if 'ZEROBASEONE' in headline.upper()]

# %% [markdown]
# # 4. 전체 표본 구하기 - 네이버뉴스 : 아이돌 그룹 별

# %% [markdown]
# ## RIIZE

# %%
### basic code source ###

# RIIZE
# searching period : 2023.10.02~2023.11.17
# search : RIIZE

import requests
from bs4 import BeautifulSoup

base_url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=RIIZE&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=1701&nso=so:dd,p:from20231002to20231117,a:all&start='
# 마지막 페이지 번호 : 1071

nums = []
for i in range(0, 1071, 10):
  if i == 0:
    nums.append(i)
  else:
    nums.append(i+1)


# 페이지 번호에 해당하는 링크를 생성하여 리스트에 추가
links = [base_url + str(i) for i in nums]

total = 0

for i in links:
  response = requests.get(url)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser') # soup에 담기
  naver_news_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True))
  naver_news_count = len(naver_news_elements)
  total += naver_news_count

# %%
url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=RIIZE&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=1701&nso=so:dd,p:from20231002to20231117,a:all&start=61'
total = 0
response = requests.get(url)
html = response.text
soup = BeautifulSoup(html, 'html.parser') # soup에 담기
naver_news_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True))
naver_news_count = len(naver_news_elements)
total += naver_news_count

print(total)
# p1 : 5
# p2 : 4
# p3 : 6
# p4 : 3
# p5 : 6
# p6 : 4
# Out:
# 5

# %%
5+4+6+3+6+4
# Out:
# 28

# %%
### basic code source ###

# RIIZE
# searching period : 2023.10.02~2023.11.17
# search : RIIZE

import requests
from bs4 import BeautifulSoup

base_url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=RIIZE&sort=1&photo=0&field=0&pd=3&ds=2023.10.02&de=2023.11.17&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=1701&nso=so:dd,p:from20231002to20231117,a:all&start='
# 마지막 페이지 번호 : 1071

nums = []
for i in range(0, 1071, 10):
  if i == 0:
    nums.append(i)
  else:
    nums.append(i+1)


# 페이지 번호에 해당하는 링크를 생성하여 리스트에 추가
links = [base_url + str(i) for i in nums]

total = 0

for i in links:
  response = requests.get(i)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser') # soup에 담기
  naver_news_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True))
  naver_news_count = len(naver_news_elements)
  total += naver_news_count
print(total)
# Out:
# 738

# %% [markdown]
# ## BoyNextDoor

# %%
### basic code source ###

# BOYNEXTDOOR
# searching period : 2023.08.07~2023.09.22
# search : BOYNEXTDOOR

import requests
from bs4 import BeautifulSoup

base_url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=BOYNEXTDOOR&sort=0&photo=0&field=0&pd=3&ds=2023.08.07&de=2023.09.22&cluster_rank=43&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:r,p:from20230807to20230922,a:all&start='
# 마지막 페이지 번호 : 1231

nums = []
for i in range(0, 1231, 10):
  if i == 0:
    nums.append(i)
  else:
    nums.append(i+1)


# 페이지 번호에 해당하는 링크를 생성하여 리스트에 추가
links = [base_url + str(i) for i in nums]

bnd_total = 0

for i in links:
  response = requests.get(i)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser') # soup에 담기
  naver_news_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True))
  naver_news_count = len(naver_news_elements)
  bnd_total += naver_news_count

print(bnd_total) # 변수명 바꾸기 전 1967
# Out:
# 0

# %% [markdown]
# ## Enhypen

# %%
### basic code source ###

# ENHYPEN
# searching period : 2023.10.23~2023.12.08
# search : ENHYPEN

import requests
from bs4 import BeautifulSoup

base_url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=ENHYPEN&sort=0&photo=0&field=0&pd=3&ds=2023.10.23&de=2023.12.08&cluster_rank=44&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=1701&nso=so:r,p:from20231023to20231208,a:all&start='
# 마지막 페이지 번호 : 1331

nums = []
for i in range(0, 1331, 10):
  if i == 0:
    nums.append(i)
  else:
    nums.append(i+1)


# 페이지 번호에 해당하는 링크를 생성하여 리스트에 추가
links = [base_url + str(i) for i in nums]

total = 0

for i in links:
  response = requests.get(i)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser') # soup에 담기
  naver_news_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True))
  naver_news_count = len(naver_news_elements)
  total += naver_news_count
print(total)
# Out:
# 2109

# %% [markdown]
# ## 투모로우바이투게더

# %%
### basic code source ###

# 투모로우바이투게더
# searching period : 2023.09.18~2023.11.03
# search : 투모로우바이투게더

import requests
from bs4 import BeautifulSoup

base_url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%ED%88%AC%EB%AA%A8%EB%A1%9C%EC%9A%B0%EB%B0%94%EC%9D%B4%ED%88%AC%EA%B2%8C%EB%8D%94&sort=0&photo=0&field=0&pd=3&ds=2023.09.18&de=2023.11.03&cluster_rank=65&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=1701&nso=so:r,p:from20230918to20231103,a:all&start='
# 마지막 페이지 번호 : 2381

nums = []
for i in range(0, 2381, 10):
  if i == 0:
    nums.append(i)
  else:
    nums.append(i+1)


# 페이지 번호에 해당하는 링크를 생성하여 리스트에 추가
links = [base_url + str(i) for i in nums]

total = 0

for i in links:
  response = requests.get(i)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser') # soup에 담기
  naver_news_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True))
  naver_news_count = len(naver_news_elements)
  total += naver_news_count
print(total)
# Out:
# 323

# %%
ex_url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%ED%88%AC%EB%AA%A8%EB%A1%9C%EC%9A%B0%EB%B0%94%EC%9D%B4%ED%88%AC%EA%B2%8C%EB%8D%94&sort=0&photo=0&field=0&pd=3&ds=2023.09.18&de=2023.11.03&cluster_rank=133&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=1701&nso=so:r,p:from20230918to20231103,a:all&start=111'

response = requests.get(ex_url)
html = response.text
soup = BeautifulSoup(html, 'html.parser') # soup에 담기

naver_news_elements = soup.find_all(lambda tag: tag.name == 'a' and '네이버뉴스' in tag.get_text(strip=True))
naver_news_count = len(naver_news_elements)
naver_news_count
# Out:
# 0

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

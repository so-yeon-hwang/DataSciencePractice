# %% [markdown]
# <a href="https://colab.research.google.com/github/so-yeon-hwang/DataSciencePractice/blob/main/Youtube_Uploading_count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('ZB1 유튜브 자체 콘텐츠 (2).xlsx')
# Out:
# <ipython-input-51-0944e75b2f31>:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   df = pd.read_excel('ZB1 유튜브 자체 콘텐츠 (2).xlsx')

# %%
df
# Out:
#       Unnamed: 0                                         Unnamed: 1  \
# 0     [ZB1_more]       [ZB1_more] ZEROBASEONE 2023 SBS 가요대전 안무 연습 🎬
# 1    [ZE_pisode]  [ZE_pisode] ZEROBASEONE (제로베이스원) 2023 Music Aw...
# 2    [ZE_pisode]  [ZE_pisode] ZEROBASEONE (제로베이스원) 2024 SEASON'S...
# 3   [ZB1_folder]  [ZB1_folder] ZEROSE! 2024년에도 함께하상 | 2023 ZEROB...
# 4     [ZB1_more]  [ZB1_more] ZEROBASEONE The 2nd Mini Album [𝗠𝗘𝗟...
# ..           ...                                                ...
# 87           NaN  ZEROBASEONE (제로베이스원) 'Back to ZEROBASE' Film B...
# 88            기타  ZEROBASEONE (제로베이스원) 'Back to ZEROBASE' Film R...
# 89           NaN  ZEROBASEONE (제로베이스원) 태래쇼 🎤 (Feat. KCON JAPAN 2...
# 90           NaN   ZEROBASEONE (제로베이스원) KCON JAPAN 2023 BEHIND EP.2
# 91           NaN   ZEROBASEONE (제로베이스원) KCON JAPAN 2023 BEHIND EP.1
#
#    Unnamed: 2    Unnamed: 3
# 0  2024-01-12    [ZB1_more]
# 1  2024-01-11   [ZE_pisode]
# 2  2023-12-30   [ZE_pisode]
# 3  2023-12-29  [ZB1_Folder]
# ...

# %%
column_name = ['old','title','date','category']
df.columns = column_name
df
# Out:
#              old                                              title  \
# 0     [ZB1_more]       [ZB1_more] ZEROBASEONE 2023 SBS 가요대전 안무 연습 🎬
# 1    [ZE_pisode]  [ZE_pisode] ZEROBASEONE (제로베이스원) 2023 Music Aw...
# 2    [ZE_pisode]  [ZE_pisode] ZEROBASEONE (제로베이스원) 2024 SEASON'S...
# 3   [ZB1_folder]  [ZB1_folder] ZEROSE! 2024년에도 함께하상 | 2023 ZEROB...
# 4     [ZB1_more]  [ZB1_more] ZEROBASEONE The 2nd Mini Album [𝗠𝗘𝗟...
# ..           ...                                                ...
# 87           NaN  ZEROBASEONE (제로베이스원) 'Back to ZEROBASE' Film B...
# 88            기타  ZEROBASEONE (제로베이스원) 'Back to ZEROBASE' Film R...
# 89           NaN  ZEROBASEONE (제로베이스원) 태래쇼 🎤 (Feat. KCON JAPAN 2...
# 90           NaN   ZEROBASEONE (제로베이스원) KCON JAPAN 2023 BEHIND EP.2
# 91           NaN   ZEROBASEONE (제로베이스원) KCON JAPAN 2023 BEHIND EP.1
#
#          date      category
# 0  2024-01-12    [ZB1_more]
# 1  2024-01-11   [ZE_pisode]
# 2  2023-12-30   [ZE_pisode]
# 3  2023-12-29  [ZB1_Folder]
# ...

# %%
df = df.drop(columns = ['old'])
df
# Out:
#                                                 title       date      category
# 0        [ZB1_more] ZEROBASEONE 2023 SBS 가요대전 안무 연습 🎬 2024-01-12    [ZB1_more]
# 1   [ZE_pisode] ZEROBASEONE (제로베이스원) 2023 Music Aw... 2024-01-11   [ZE_pisode]
# 2   [ZE_pisode] ZEROBASEONE (제로베이스원) 2024 SEASON'S... 2023-12-30   [ZE_pisode]
# 3   [ZB1_folder] ZEROSE! 2024년에도 함께하상 | 2023 ZEROB... 2023-12-29  [ZB1_Folder]
# 4   [ZB1_more] ZEROBASEONE The 2nd Mini Album [𝗠𝗘𝗟... 2023-12-28    [ZB1_more]
# ..                                                ...        ...           ...
# 87  ZEROBASEONE (제로베이스원) 'Back to ZEROBASE' Film B... 2023-06-25           NaN
# 88  ZEROBASEONE (제로베이스원) 'Back to ZEROBASE' Film R... 2023-06-24           etc
# 89  ZEROBASEONE (제로베이스원) 태래쇼 🎤 (Feat. KCON JAPAN 2... 2023-06-07           NaN
# 90   ZEROBASEONE (제로베이스원) KCON JAPAN 2023 BEHIND EP.2 2023-06-05           NaN
# 91   ZEROBASEONE (제로베이스원) KCON JAPAN 2023 BEHIND EP.1 2023-06-02           NaN
#
# [92 rows x 3 columns]

# %%
print('1. unique()')
print(df['category'].unique())
print()
print('2. value_counts()')
print(df['category'].value_counts())
# Out:
# 1. unique()
# ['[ZB1_more]' '[ZE_pisode]' '[ZB1_Folder]' 'etc' '[ZBTV]' '[ZB1 CAM]'
#  '[새로운 녹음]' nan]
#
# 2. value_counts()
# [ZE_pisode]     32
# [ZBTV]          12
# [ZB1 CAM]       12
# [ZB1_more]      10
# etc             10
# [ZB1_Folder]     8
# [새로운 녹음]         4
# Name: category, dtype: int64

# %%
counts = df['category'].value_counts()
counts
# Out:
# [ZE_pisode]     32
# [ZBTV]          12
# [ZB1 CAM]       12
# [ZB1_more]      10
# etc             10
# [ZB1_Folder]     8
# [새로운 녹음]         4
# Name: category, dtype: int64

# %%
category = list(df['category'].unique())
category
# Out:
# ['[ZB1_more]',
#  '[ZE_pisode]',
#  '[ZB1_Folder]',
#  'etc',
#  '[ZBTV]',
#  '[ZB1 CAM]',
#  '[새로운 녹음]',
#  nan]

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %%
category_counts = df['category'].value_counts()
# visualization
plt.figure(figsize = (15,12))

# counting above
for i, count in enumerate(category_counts):
    plt.text(i, count + 0.1, str(count), ha='center', va='bottom',fontsize=20)

plt.bar(category_counts.index, category_counts.values)
plt.title('Youtube Contents counting per Category',fontsize=30)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49352 (\N{HANGUL SYLLABLE SAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45433 (\N{HANGUL SYLLABLE NOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df['month']
# Out:
# 0     2024-01
# 1     2024-01
# 2     2023-12
# 3     2023-12
# 4     2023-12
#        ...
# 87    2023-06
# 88    2023-06
# 89    2023-06
# 90    2023-06
# 91    2023-06
# Name: month, Length: 92, dtype: period[M]

# %%
uploads_by_month
# Out:
#      month  upload_count
# 0  2023-06             5
# 1  2023-07            12
# 2  2023-08            11
# 3  2023-09            15
# 4  2023-10            15
# 5  2023-11            19
# 6  2023-12            13
# 7  2024-01             2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df['date'] = pd.to_datetime(df['date'])

df['month'] = df['date'].dt.to_period('M')

uploads_by_month = df.groupby('month').size().reset_index(name='upload_count')

plt.figure(figsize=(10, 6))
sns.barplot(x='month', y='upload_count', data=uploads_by_month, color = 'skyblue')
plt.title('Monthly Upload Count')

plt.xlabel('Month')
plt.yticks([0,5,10,15,20])
plt.ylabel('Upload Count')
plt.show()
